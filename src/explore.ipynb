# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd

df_test = pd.read_csv('https://raw.githubusercontent.com/bartowen/desicion_tree_algo/refs/heads/main/data/processed/clean_test.csv')
df_train = pd.read_csv('https://raw.githubusercontent.com/bartowen/desicion_tree_algo/refs/heads/main/data/processed/clean_train.csv')

df_test.head()
# Out:
#    Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0          6.0     98.0           33.0    190.0  34.0
# 1          2.0    112.0           32.0    125.0  35.7
# 2          2.0    108.0           29.0    125.0  30.8
# 3          8.0    107.0           29.0    125.0  24.6
# 4          7.0    136.0           29.0    125.0  29.9
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.430  43.0        0
# 1                     0.148  21.0        0
# 2                     0.158  21.0        0
# 3                     0.856  34.0        0
# 4                     0.210  50.0        0

# %%
df_train.head()
# Out:
#    Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0          2.0     84.0           29.0    125.0  32.3
# 1          9.0    112.0           24.0    125.0  28.2
# 2          1.0    139.0           19.0     83.0  28.7
# 3          0.0    161.0           29.0    125.0  21.9
# 4          6.0    134.0           37.0    370.0  46.2
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.304  21.0        0
# 1                     1.282  50.0        1
# 2                     0.654  22.0        0
# 3                     0.254  65.0        0
# 4                     0.238  46.0        1
